# %%
import numpy as np

class Rosenbrock:
  def __init__(self, a, b):
    self.a = a
    self.b = b
  
  def f(self, x):
    return (self.a - x[0])**2 + b*(x[1]-x[0]**2)**2
  
  def g(self, x):
    return np.array([-2*(self.a - x[0]) - 4*self.b*x[0]*(x[1]-x[0]**2)])
  
  def j
