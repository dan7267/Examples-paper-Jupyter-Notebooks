# %%
#a Nyquist diagram is just an argand diagram.
import numpy as np
import matplotlib.pyplot as plt

w = np.linspace(0, 10000, 100)
T = 5

def G(w):
  return 2 /(-1+1*j*w*T)

w_real = G(w).real
w_imaginary = G(w).imag

print(w_real)
print(w_imaginary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6d8ab8e05fd9> in <cell line: 11>()
#       9   return 2 /(-1+1*j*w*T)
#      10
# ---> 11 w_real = G(w).real
#      12 w_imaginary = G(w).imag
#      13
#
# <ipython-input-1-6d8ab8e05fd9> in G(w)
#       7
#       8 def G(w):
# ----> 9   return 2 /(-1+1*j*w*T)
#      10
#      11 w_real = G(w).real
#
# NameError: name 'j' is not defined
